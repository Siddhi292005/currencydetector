# %%
from google.colab import drive
drive.mount('/content/drive')

import os, shutil, json

newdatapath="/content/drive/MyDrive/Datasetsv2"
SAVE_DIR="/content/drive/MyDrive/currencydetector1"
os.makedirs('/root/.kaggle', exist_ok=True)
shutil.copy('/content/drive/MyDrive/kaggle.json', '/root/.kaggle/kaggle.json')
os.chmod('/root/.kaggle/kaggle.json', 0o600)
print("kaggle configured")
# Out:
# Mounted at /content/drive
# kaggle configured

# %%
classes=[
    'INR10','INR20','INR50','INR100','INR200','INR500',
    'USD1', 'USD5', 'USD10', 'USD20', 'USD50', 'USD100',
    'GBP5', 'GBP10', 'GBP20', 'GBP50',
    'EUR5', 'EUR10', 'EUR20', 'EUR50', 'EUR100', 'EUR_200',
    'JPY1000', 'JPY5000', 'JPY10000',
    'AED5', 'AED10', 'AED20', 'AED50', 'AED100', 'AED200', 'AED500',
]

for cls in classes:
  os.makedirs(os.path.join(newdatapath,cls),exist_ok=True)
print(f"created {len(classes)} folders")
for cls in sorted(os.listdir(newdatapath)):
  print(f"{cls}")
# Out:
# created 32 folders
# AED10
# AED100
# AED20
# AED200
# AED5
# AED50
# AED500
# EUR10
# EUR100
# EUR20
# EUR5
# EUR50
# EUR_10
# EUR_100
# EUR_20
# EUR_200
# EUR_5
# EUR_50
# GBP10
# GBP20
# GBP5
# GBP50
# INR10
# INR100
# INR20
# INR200
# INR50
# INR500
# INR500USD1
# INR_10
# INR_100
# INR_20
# INR_200
# INR_50
# INR_500
# JPY1000
# JPY10000
# JPY5000
# USD1
# USD10
# USD100
# USD20
# USD5
# USD50
# USD_1
# USD_10
# USD_100
# USD_5
# USD_50

# %%
oldtrain="/content/drive/MyDrive/Datasets_split/train"
inrmap={
    '10':'INR10',
    '20':'INR20',
    '50':'INR50',
    '100':'INR100',
    '200':'INR200',
    '500':'INR500',

}

for oldcls,newcls in inrmap.items():
  src=os.path.join(oldtrain,oldcls)
  dst=os.path.join(newdatapath,newcls)

  if not os.path.join(newdatapath,newcls):
    print(f"not found: {src}")
    continue
  copied=0
  for fname in os.listdir(src):
    if fname.lower().endswith(('.jpg','.jpeg','.png')):
      shutil.copy(
          os.path.join(src,fname),
          os.path.join(dst,f"inr_{fname}")
      )

      copied+=1
    print(f"{oldcls}->{newcls}:{copied} images")
print("\n inr data migrated")
# Out:
# 10->INR10:1 images
# 10->INR10:2 images
# 10->INR10:3 images
# 10->INR10:4 images
# 10->INR10:5 images
# 10->INR10:6 images
# 10->INR10:7 images
# 10->INR10:8 images
# 10->INR10:9 images
# 10->INR10:10 images
# 10->INR10:11 images
# 10->INR10:12 images
# 10->INR10:13 images
# 10->INR10:14 images
# 10->INR10:15 images
# 10->INR10:16 images
# 10->INR10:17 images
# 10->INR10:18 images
# 10->INR10:19 images
# 10->INR10:20 images
# 10->INR10:21 images
# 10->INR10:22 images
# 10->INR10:23 images
# 10->INR10:24 images
# 10->INR10:25 images
# 10->INR10:26 images
# 10->INR10:27 images
# 10->INR10:28 images
# 10->INR10:29 images
# 10->INR10:30 images
# 10->INR10:31 images
# 10->INR10:32 images
# 10->INR10:33 images
# 10->INR10:34 images
# 10->INR10:35 images
# 10->INR10:36 images
# 10->INR10:37 images
# 10->INR10:38 images
# 10->INR10:39 images
# 10->INR10:40 images
# 10->INR10:41 images
# 10->INR10:42 images
# 10->INR10:43 images
# 10->INR10:44 images
# 10->INR10:45 images
# ...

# %%
 #downloading the usd dataset
# !kaggle datasets download -d abhishtagatya/imgspnusd -p /content/usd_data --unzip
print("USD downloaded")

print("USD folder structure:")
for root, dirs, files in os.walk('/content/usd_data'):
    depth = root.replace('/content/usd_data', '').count(os.sep)
    if depth <= 2:
        indent = '  ' * depth
        print(f"{indent}{os.path.basename(root)}/")
        if depth >= 1 and files:
            print(f"{indent}  {len(files)} files")
# Out:
# 403 Client Error: Forbidden for url: https://api.kaggle.com/v1/datasets.DatasetApiService/GetDatasetMetadata
# USD downloaded
# USD folder structure:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1863/3472785514.py in <cell line: 0>()
#       4
#       5 print("USD folder structure:")
# ----> 6 for root, dirs, files in os.walk('/content/usd_data'):
#       7    depth = root.replace('/content/usd_data', '').count(os.sep)
#       8    if depth <= 2:
#
# NameError: name 'os' is not defined

# %%
# !kaggle datasets download -d validmodel/euro-banknotes -p /content/eur_data --unzip
print("EUR downloaded")

print("EUR folder structure:")
for root, dirs, files in os.walk('/content/eur_data'):
    depth = root.replace('/content/eur_data', '').count(os.sep)
    if depth <= 2:
        indent = '  ' * depth
        print(f"{indent}{os.path.basename(root)}/")
        if depth >= 1 and files:
            print(f"{indent}  {len(files)} files")
# Out:
# 403 Client Error: Forbidden for url: https://api.kaggle.com/v1/datasets.DatasetApiService/GetDatasetMetadata
# EUR downloaded
# EUR folder structure:

# %%
print("AED datasets:")
# !kaggle datasets list -s "UAE dirham currency" --sort-by votes

print("\nWorld currency (might have AED):")
# !kaggle datasets list -s "world currency banknote" --sort-by votes

print("\nGeneral currency recognition:")
# !kaggle datasets list -s "currency recognition dataset" --sort-by votes
# Out:
# AED datasets:
# ref                                                             title                                                    size  lastUpdated                 downloadCount  voteCount  usabilityRating
# --------------------------------------------------------------  ------------------------------------------------  -----------  --------------------------  -------------  ---------  ---------------
# imtkaggleteam/dollar-vs-asian-currencies                        Dollar Vs Asian Currencies                             289930  2023-05-02 09:53:11.797000           1349        146                1
# keyushnisar/in-the-wild-currency-images                         In-the-Wild Currency Images                       10098756780  2025-08-27 06:41:47.067000            190          6            0.875
# ...

# %%
print("Search 1:")
# !kaggle datasets list -s "dirham banknote images" --sort-by votes

print("\nSearch 2:")
# !kaggle datasets list -s "UAE currency notes images" --sort-by votes

print("\nSearch 3:")
# !kaggle datasets list -s "arabic currency banknote" --sort-by votes

print("\nSearch 4:")
# !kaggle datasets list -s "middle east currency notes" --sort-by votes
# Out:
# Search 1:
# No datasets found
#
# Search 2:
# No datasets found
#
# Search 3:
# ref             title          size  lastUpdated                 downloadCount  voteCount  usabilityRating
# --------------  -------  ----------  --------------------------  -------------  ---------  ---------------
# gfbati/alfloos  AlFloos   889492199  2024-03-24 08:20:28.327000            149          6  0.8125
#
# Search 4:
# ref                                                    title                                            size  lastUpdated                 downloadCount  voteCount  usabilityRating
# -----------------------------------------------------  -----------------------------------------  ----------  --------------------------  -------------  ---------  ---------------
# kanchana1990/central-bank-rates-intelligence-19452026  Central Bank Rates Intelligence 1945–2026      625247  2026-03-18 02:07:33.570000            388         34                1
# ...

# %%
print("Search 1- swiss franc:")
# !kaggle datasets list -s "swiss franc banknote" --sort-by votes
# Out:
# Search 1- swiss franc:
# No datasets found

# %%
print("search 2- CHF currency")
# !kaggle datasets list -s "CHF currency notes images" --sort-by votes
# Out:
# search 2- CHF currency
# No datasets found

# %%
print("search 2- chinese yuan")
# !kaggle datasets list -s "chinese yuan renminbi banknote" --sort-by votes
# Out:
# search 2- chinese yuan
# No datasets found

# %%
print("search 2- rmb currency")
# !kaggle datasets list -s "rmb currency notes images" --sort-by votes
# Out:
# search 2- rmb currency
# No datasets found

# %%
print("\nSearch 5 — CNY banknote:")
# !kaggle datasets list -s "CNY banknote classification" --sort-by votes
# Out:
# Search 5 — CNY banknote:
# No datasets found

# %%
print("\nSearch 5 — euro banknote:")
# !kaggle datasets list -s "euro banknote" --sort-by votes
# Out:
# Search 5 — euro banknote:
# No datasets found

# %%
print("\nSearch 5:")
# !kaggle datasets list -s "euro currency notes" --sort-by votes
# Out:
# Search 5:
# ref                                                          title                                              size  lastUpdated                 downloadCount  voteCount  usabilityRating
# -----------------------------------------------------------  -------------------------------------------  ----------  --------------------------  -------------  ---------  ---------------
# macrosynergy/fixed-income-returns-and-macro-trends           JPMaQS Quantamental Indicators                 32934147  2023-12-14 11:23:22.880000           1718         60                1
# youneseloiarm/global-economic-calendar                       Global Economic Calendar                        6937287  2025-10-26 21:12:30.210000            759         53                1
# asimislam/30-yrs-stock-market-data                           Stock Market 30-yr Dataset (1995-2025)          1038302  2026-01-28 18:13:19.910000           1744         30                1
# ...

# %%
print("Search 1:")
# !kaggle datasets list -s "euro notes banknote recognition" --sort-by votes

print("\nSearch 2:")
# !kaggle datasets list -s "EUR banknote denomination" --sort-by votes

print("\nSearch 3:")
# !kaggle datasets list -s "european banknote dataset" --sort-by votes

print("\nSearch 4:")
# !kaggle datasets list -s "currency bill classification deep learning" --sort-by votes

print("\nSearch 5:")
# !kaggle datasets list -s "banknote dataset multiple denominations" --sort-by votes
# Out:
# Search 1:
# No datasets found
#
# Search 2:
# No datasets found
#
# Search 3:
# No datasets found
#
# Search 4:
# No datasets found
#
# Search 5:
# ref                                                                     title                                                     size  lastUpdated                 downloadCount  voteCount  usabilityRating
# ----------------------------------------------------------------------  --------------------------------------------------  ----------  --------------------------  -------------  ---------  ---------------
# shuvokumarbasak2030/bangladeshi-currency-oldnewcoins-and-notes-dataset  Bangladeshi Currency OldNew(Coins & Notes) Dataset  1255409807  2025-02-06 13:54:35.527000             65         17  0.8125
# belalsafy/egyptian-new-currency-2023                                    Egyptian New Currency 2023                           413912034  2023-12-17 07:26:45.820000            954         12  0.5625
# ...

# %%
print("Search 1:")
# !kaggle datasets list -s "euro" --sort-by votes --max-size 5000

print("\nSearch 2:")
# !kaggle datasets list -s "euros notes" --sort-by votes

print("\nSearch 3:")
# !kaggle datasets list -s "banknote euro detection" --sort-by votes

print("\nSearch 4:")
# !kaggle datasets list -s "money euro classification" --sort-by votes
# Out:
# Search 1:
# ref                                                            title                                                    size  lastUpdated                 downloadCount  voteCount  usabilityRating
# -------------------------------------------------------------  -------------------------------------------------  ----------  --------------------------  -------------  ---------  ---------------
# anandhuh/latest-covid19-data-of-european-countries             Covid-19 in Europe - Latest Data                         2224  2023-01-19 12:22:26.407000           1177         73                1
# mauryansshivam/spotify-revenue-expenses-and-its-premium-users  Spotify Revenue, Expenses and Its Premium Users          1246  2023-06-06 18:39:16.927000           4595         66                1
# ...

# %%
# !pip install roboflow -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.9/207.9 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 20.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 69.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 108.0 MB/s eta 0:00:00

# %%
from roboflow import Roboflow

# %%
# !pip install roboflow -q

from roboflow import Roboflow

rf = Roboflow(api_key="your_api_key_here")  # paste your key here

project = rf.workspace("money-qwneh").project("euro-dj7ew")

# Check available versions
versions = project.versions()
print("Available versions:")
for v in versions:
    print(f"  Version {v.version}: {v.exports}")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_8698/2428187710.py in <cell line: 0>()
#       3 from roboflow import Roboflow
#       4
# ----> 5 rf = Roboflow(api_key="your_api_key_here")  # paste your key here
#       6
#       7 project = rf.workspace("money-qwneh").project("euro-dj7ew")
#
# /usr/local/lib/python3.12/dist-packages/roboflow/__init__.py in __init__(self, api_key, model_format, notebook)
#     216         self.notebook = notebook
#     217         self.onboarding = False
# --> 218         self.auth()
#     219
#     220     def auth(self):
#
# /usr/local/lib/python3.12/dist-packages/roboflow/__init__.py in auth(self)
#     219
#     220     def auth(self):
# --> 221         r = check_key(self.api_key, self.model_format, self.notebook)
#     222
#     223         if r == "onboarding":
#
# ...

# %%
pip install inference-sdk

# %%
# !pip install roboflow -q

from roboflow import Roboflow

rf = Roboflow(api_key="J4qAcTsaQ9yULZhYx17s")

project = rf.workspace("money-qwneh").project("euro-dj7ew")
dataset = project.version(1).download("folder", location="/content/eur_data")
print(" Downloaded")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.9/207.9 kB 7.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 12.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 49.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 74.9 MB/s eta 0:00:00
# loading Roboflow workspace...
# loading Roboflow project...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_3291/1107654492.py in <cell line: 0>()
#       6
#       7 project = rf.workspace("money-qwneh").project("euro-dj7ew")
# ----> 8 dataset = project.version(1).download("folder", location="/content/eur_data")
#       9 print(" Downloaded")
#
# /usr/local/lib/python3.12/dist-packages/roboflow/core/project.py in version(self, version_number, local)
# ...

# %%
project = rf.workspace("money-qwneh").project("euro-dj7ew")

# List all versions
print("Available versions:")
for version in project.versions():
    print(f"  Version: {version.version}")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Available versions:

# %%
from roboflow import Roboflow

rf = Roboflow(api_key="J4qAcTsaQ9yULZhYx17s")
project = rf.workspace("money-qwneh").project("euro-dj7ew")

# Try different versions
for v in [1, 2, 3, 4, 5]:
    try:
        dataset = project.version(v).download("folder", location=f"/content/eur_data_v{v}")
        print(f"Version {v} downloaded")
        break
    except Exception as e:
        print(f"Version {v}: {e}")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Version 1: Version number 1 is not found.
# Version 2: Version number 2 is not found.
# Version 3: Version number 3 is not found.
# Version 4: Version number 4 is not found.
# Version 5: Version number 5 is not found.

# %%
# Search for working euro datasets
# !pip install roboflow -q
from roboflow import Roboflow

rf = Roboflow(api_key="J4qAcTsaQ9yULZhYx17s")

# Try these known working datasets
datasets_to_try = [
    ("da-currency-recognition", "currency-recognition-rev.1"),
    ("tatmantech", "worldwide_currency"),
    ("money-recognition", "banknotes-recognition"),
]

for workspace, project_name in datasets_to_try:
    try:
        project = rf.workspace(workspace).project(project_name)
        print(f"✅ Found: {workspace}/{project_name}")
        versions = project.versions()
        print(f"   Versions: {len(versions)}")
    except Exception as e:
        print(f"❌ {workspace}/{project_name}: {e}")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.9/207.9 kB 8.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 12.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 50.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 64.3 MB/s eta 0:00:00
# loading Roboflow workspace...
# loading Roboflow project...
# ✅ Found: da-currency-recognition/currency-recognition-rev.1
#    Versions: 1
# loading Roboflow workspace...
# loading Roboflow project...
# ✅ Found: tatmantech/worldwide_currency
#    Versions: 5
# loading Roboflow workspace...
# loading Roboflow project...
# ✅ Found: money-recognition/banknotes-recognition
#    Versions: 2

# %%
from roboflow import Roboflow

rf = Roboflow(api_key="J4qAcTsaQ9yULZhYx17s")

# Check dataset 1 — currency-recognition
print("=== Dataset 1: currency-recognition-rev.1 ===")
project1 = rf.workspace("da-currency-recognition").project("currency-recognition-rev.1")
v1 = project1.version(1)
print(f"Classes: {v1.classes}")

# Check dataset 2 — worldwide_currency
print("\n=== Dataset 2: worldwide_currency ===")
project2 = rf.workspace("tatmantech").project("worldwide_currency")
v2 = project2.version(1)
print(f"Classes: {v2.classes}")

# Check dataset 3 — banknotes-recognition
print("\n=== Dataset 3: banknotes-recognition ===")
project3 = rf.workspace("money-recognition").project("banknotes-recognition")
v3 = project3.version(1)
print(f"Classes: {v3.classes}")
# Out:
# === Dataset 1: currency-recognition-rev.1 ===
# loading Roboflow workspace...
# loading Roboflow project...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3143/2315366566.py in <cell line: 0>()
#       7 project1 = rf.workspace("da-currency-recognition").project("currency-recognition-rev.1")
#       8 v1 = project1.version(1)
# ----> 9 print(f"Classes: {v1.classes}")
#      10
#      11 # Check dataset 2 — worldwide_currency
#
# AttributeError: 'Version' object has no attribute 'classes'

# %%
import os

print("=== USD structure ===")
for root, dirs, files in os.walk('/content/usd_data'):
    depth = root.replace('/content/usd_data', '').count(os.sep)
    if depth <= 3:
        indent = '  ' * depth
        print(f"{indent}{os.path.basename(root)}/")
        if depth >= 2 and files:
            print(f"{indent}  {len(files)} files")

print("\n=== EUR structure ===")
for root, dirs, files in os.walk('/content/eur_data'):
    depth = root.replace('/content/eur_data', '').count(os.sep)
    if depth <= 3:
        indent = '  ' * depth
        print(f"{indent}{os.path.basename(root)}/")
        if depth >= 2 and files:
            print(f"{indent}  {len(files)} files")
# Out:
# === USD structure ===
#
# === EUR structure ===

# %%
import os, shutil

eur_src = '/content/drive/MyDrive/train'
eur_dst = '/content/eur_sorted'

# EUR denomination mapping
eur_denoms = ['5', '10', '20', '50', '100', '200']

# Create destination folders
for d in eur_denoms:
    os.makedirs(os.path.join(eur_dst, f'EUR_{d}'), exist_ok=True)

# Sort images by denomination from filename
sorted_count = {}
skipped = []

for fname in os.listdir(eur_src):
    if not fname.lower().endswith(('.jpg', '.jpeg', '.png')):
        continue

    matched = False
    # Check filename prefix — order matters (check 100 before 10, 50 before 5)
    for denom in ['200', '100', '50', '20', '10', '5']:
        if fname.startswith(f'{denom}Euro') or fname.lower().startswith(f'{denom}euro'):
            dst_folder = os.path.join(eur_dst, f'EUR_{denom}')
            shutil.copy(os.path.join(eur_src, fname),
                        os.path.join(dst_folder, fname))
            sorted_count[f'EUR_{denom}'] = sorted_count.get(f'EUR_{denom}', 0) + 1
            matched = True
            break

    if not matched:
        skipped.append(fname)

print("=== EUR sorted counts ===")
for cls, count in sorted(sorted_count.items()):
    print(f"  {cls}: {count} images")

print(f"\nSkipped {len(skipped)} unmatched files")
if skipped:
    print("Sample skipped:", skipped[:5])
# Out:
# === EUR sorted counts ===
#   EUR_10: 365 images
#   EUR_100: 337 images
#   EUR_20: 370 images
#   EUR_5: 369 images
#   EUR_50: 361 images
#
# Skipped 0 unmatched files

# %%
print("Search 1:")
# !kaggle datasets list -s "US dollar bill classification" --sort-by votes

print("\nSearch 2:")
# !kaggle datasets list -s "american currency notes" --sort-by votes

print("\nSearch 3:")
# !kaggle datasets list -s "USD banknote denomination" --sort-by votes
# Out:
# Search 1:
# No datasets found
#
# Search 2:
# ref                                                                title                                                     size  lastUpdated                 downloadCount  voteCount  usabilityRating
# -----------------------------------------------------------------  --------------------------------------------------  ----------  --------------------------  -------------  ---------  ---------------
# lucafrance/the-world-factbook-by-cia                               The World Factbook by CIA                              4940588  2025-03-14 19:36:06.400000           8522        182  0.9411765
# renecardoso/housing-prices-in-cdmx                                 Housing Prices in CDMX                                 1446117  2025-07-31 00:05:16.147000           1034         19  1
# ...

# %%
import os

usd_path = '/content/drive/MyDrive/USA currency/USA currency 2'
print("=== USD counts ===")
for cls in sorted(os.listdir(usd_path)):
    cls_path = os.path.join(usd_path, cls)
    if os.path.isdir(cls_path) and cls != 'Test Set' and not cls.startswith('.'):
        count = len([f for f in os.listdir(cls_path)
                     if f.lower().endswith(('.jpg','.jpeg','.png'))])
        print(f"  {cls}: {count} images")

# Also check Test Set
test_path = os.path.join(usd_path, 'Test Set')
if os.path.exists(test_path):
    print("\n  Test Set/")
    for cls in sorted(os.listdir(test_path)):
        cls_path = os.path.join(test_path, cls)
        if os.path.isdir(cls_path):
            count = len([f for f in os.listdir(cls_path)
                         if f.lower().endswith(('.jpg','.jpeg','.png'))])
            print(f"    {cls}: {count} images")
# Out:
# === USD counts ===
#   1 Dollar: 605 images
#   10 Dollar: 764 images
#   100 Dollar: 618 images
#   2 Doolar: 617 images
#   5 Dollar: 617 images
#   50 Dollar: 685 images
#
#   Test Set/

# %%
import os, shutil

usd_src = '/content/drive/MyDrive/USA currency/USA currency 2'
newdatapath = '/content/drive/MyDrive/Datasetsv2'

usd_map = {
    '1 Dollar':   'USD_1',
    '5 Dollar':   'USD_5',
    '10 Dollar':  'USD_10',
    '50 Dollar':  'USD_50',
    '100 Dollar': 'USD_100',

}

for folder, cls in usd_map.items():
    src = os.path.join(usd_src, folder)
    dst = os.path.join(newdatapath, cls)
    os.makedirs(dst, exist_ok=True)

    copied = 0
    for fname in os.listdir(src):
        if fname.lower().endswith(('.jpg', '.jpeg', '.png')):
            shutil.copy(
                os.path.join(src, fname),
                os.path.join(dst, f"usd_{fname}")
            )
            copied += 1
    print(f"  {folder} → {cls}: {copied} images")

print("\nUSD copied")
# Out:
#   1 Dollar → USD_1: 605 images
#   5 Dollar → USD_5: 617 images
#   10 Dollar → USD_10: 764 images
#   50 Dollar → USD_50: 685 images
#   100 Dollar → USD_100: 618 images
#
# USD copied

# %%
import os, shutil

usd_src = '/content/drive/MyDrive/USA currency/USA currency 2'
newdatapath = '/content/drive/MyDrive/Datasetsv2'

# Map folder names to class names
usd_map = {
    '1 Dollar':   'USD_1',
    '5 Dollar':   'USD_5',
    '10 Dollar':  'USD_10',
    '50 Dollar':  'USD_50',
    '100 Dollar': 'USD_100',
    # skipping 2 Dollar — not commonly circulated
}

for folder, cls in usd_map.items():
    src = os.path.join(usd_src, folder)
    dst = os.path.join(newdatapath, cls)
    os.makedirs(dst, exist_ok=True)

    copied = 0
    for fname in os.listdir(src):
        if fname.lower().endswith(('.jpg', '.jpeg', '.png')):
            shutil.copy(
                os.path.join(src, fname),
                os.path.join(dst, f"usd_{fname}")
            )
            copied += 1
    print(f"  {folder} → {cls}: {copied} images")

print("\nUSD copied")
# Out:
#   1 Dollar → USD_1: 605 images
#   5 Dollar → USD_5: 617 images
#   10 Dollar → USD_10: 764 images
#   50 Dollar → USD_50: 685 images
#   100 Dollar → USD_100: 618 images
#
# USD copied

# %%
eur_src = '/content/eur_sorted'

eur_map = {
    'EUR_5':   'EUR_5',
    'EUR_10':  'EUR_10',
    'EUR_20':  'EUR_20',
    'EUR_50':  'EUR_50',
    'EUR_100': 'EUR_100',
}

for folder, cls in eur_map.items():
    src = os.path.join(eur_src, folder)
    dst = os.path.join(newdatapath, cls)
    os.makedirs(dst, exist_ok=True)

    if not os.path.exists(src):
        print(f"⚠️ Not found: {src}")
        continue

    copied = 0
    for fname in os.listdir(src):
        if fname.lower().endswith(('.jpg', '.jpeg', '.png')):
            shutil.copy(
                os.path.join(src, fname),
                os.path.join(dst, f"eur_{fname}")
            )
            copied += 1
    print(f"  {folder} → {cls}: {copied} images")

print("\n EUR copied")
# Out:
#   EUR_5 → EUR_5: 369 images
#   EUR_10 → EUR_10: 365 images
#   EUR_20 → EUR_20: 370 images
#   EUR_50 → EUR_50: 361 images
#   EUR_100 → EUR_100: 337 images
#
#  EUR copied

# %%
inr_src = '/content/drive/MyDrive/Datasets_split/train'

inr_map = {
    '10':  'INR_10',
    '20':  'INR_20',
    '50':  'INR_50',
    '100': 'INR_100',
    '200': 'INR_200',
    '500': 'INR_500',
}

for folder, cls in inr_map.items():
    src = os.path.join(inr_src, folder)
    dst = os.path.join(newdatapath, cls)
    os.makedirs(dst, exist_ok=True)

    if not os.path.exists(src):
        print(f"Not found: {src}")
        continue

    copied = 0
    for fname in os.listdir(src):
        if fname.lower().endswith(('.jpg', '.jpeg', '.png')):
            shutil.copy(
                os.path.join(src, fname),
                os.path.join(dst, f"inr_{fname}")
            )
            copied += 1
    print(f"  {folder} → {cls}: {copied} images")

print("\n INR copied")
# Out:
#   10 → INR_10: 769 images
#   20 → INR_20: 745 images
#   50 → INR_50: 724 images
#   100 → INR_100: 674 images
#   200 → INR_200: 791 images
#   500 → INR_500: 704 images
#
#  INR copied

# %%
import os

newdatapath = '/content/drive/MyDrive/Datasetsv2'

print("=== Datasetsv2 final counts ===")
total = 0
classes = []
for cls in sorted(os.listdir(newdatapath)):
    cls_path = os.path.join(newdatapath, cls)
    if os.path.isdir(cls_path) and not cls.startswith('.'):
        count = len([f for f in os.listdir(cls_path)
                     if f.lower().endswith(('.jpg','.jpeg','.png'))])
        total += count
        classes.append(cls)
        flag = "✅" if count >= 200 else "⚠️"
        print(f"  {flag} {cls:<12} {count} images")

print(f"\n  Total images : {total}")
print(f"  Total classes: {len(classes)}")
# Out:
# === Datasetsv2 final counts ===
#   ⚠️ AED10        0 images
#   ⚠️ AED100       0 images
#   ⚠️ AED20        0 images
#   ⚠️ AED200       0 images
#   ⚠️ AED5         0 images
#   ⚠️ AED50        0 images
#   ⚠️ AED500       0 images
#   ⚠️ EUR10        0 images
#   ⚠️ EUR100       0 images
#   ⚠️ EUR20        0 images
#   ⚠️ EUR5         0 images
#   ⚠️ EUR50        0 images
#   ✅ EUR_10       365 images
#   ✅ EUR_100      337 images
#   ✅ EUR_20       370 images
#   ⚠️ EUR_200      0 images
#   ✅ EUR_5        369 images
#   ✅ EUR_50       361 images
#   ⚠️ GBP10        0 images
#   ⚠️ GBP20        0 images
#   ⚠️ GBP5         0 images
#   ⚠️ GBP50        0 images
#   ✅ INR10        769 images
#   ✅ INR100       674 images
#   ✅ INR20        745 images
#   ✅ INR200       791 images
#   ✅ INR50        724 images
#   ✅ INR500       704 images
#   ⚠️ INR500USD1   0 images
#   ✅ INR_10       769 images
#   ✅ INR_100      674 images
#   ✅ INR_20       745 images
# ...

# %%
import os, shutil

newdatapath = '/content/drive/MyDrive/Datasetsv2'

keep = [
    'INR_10', 'INR_20', 'INR_50', 'INR_100', 'INR_200', 'INR_500',
    'USD_1', 'USD_5', 'USD_10', 'USD_50', 'USD_100',
    'EUR_5', 'EUR_10', 'EUR_20', 'EUR_50', 'EUR_100',
]

# Delete everything else
for cls in os.listdir(newdatapath):
    cls_path = os.path.join(newdatapath, cls)
    if os.path.isdir(cls_path) and cls not in keep:
        shutil.rmtree(cls_path)
        print(f"Deleted: {cls}")

print("\n✅ Cleanup complete")
# Out:
# Deleted: INR10
# Deleted: INR20
# Deleted: INR50
# Deleted: INR100
# Deleted: INR200
# Deleted: INR500USD1
# Deleted: USD5
# Deleted: USD10
# Deleted: USD20
# Deleted: USD50
# Deleted: USD100
# Deleted: GBP5
# Deleted: GBP10
# Deleted: GBP20
# Deleted: GBP50
# Deleted: EUR5
# Deleted: EUR10
# Deleted: EUR20
# Deleted: EUR50
# Deleted: EUR100
# Deleted: EUR_200
# Deleted: JPY1000
# Deleted: JPY5000
# Deleted: JPY10000
# Deleted: AED5
# Deleted: AED10
# Deleted: AED20
# Deleted: AED50
# Deleted: AED100
# Deleted: AED200
# Deleted: AED500
# Deleted: INR500
# Deleted: USD1
#
# ✅ Cleanup complete

# %%
import os

newdatapath = '/content/drive/MyDrive/Datasetsv2'

print("=== Datasetsv2 final counts ===")
total = 0
classes = []
for cls in sorted(os.listdir(newdatapath)):
    cls_path = os.path.join(newdatapath, cls)
    if os.path.isdir(cls_path) and not cls.startswith('.'):
        count = len([f for f in os.listdir(cls_path)
                     if f.lower().endswith(('.jpg','.jpeg','.png'))])
        total += count
        classes.append(cls)
        flag = "✅" if count >= 200 else "⚠️"
        print(f"  {flag} {cls:<12} {count} images")

print(f"\n  Total images : {total}")
print(f"  Total classes: {len(classes)}")
# Out:
# === Datasetsv2 final counts ===
#   ✅ EUR_10       365 images
#   ✅ EUR_100      337 images
#   ✅ EUR_20       370 images
#   ✅ EUR_5        369 images
#   ✅ EUR_50       361 images
#   ✅ INR_10       769 images
#   ✅ INR_100      674 images
#   ✅ INR_20       745 images
#   ✅ INR_200      791 images
#   ✅ INR_50       724 images
#   ✅ INR_500      704 images
#   ✅ USD_1        605 images
#   ✅ USD_10       764 images
#   ✅ USD_100      618 images
#   ✅ USD_5        617 images
#   ✅ USD_50       685 images
#
#   Total images : 9498
#   Total classes: 16
