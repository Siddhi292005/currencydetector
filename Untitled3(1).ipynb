# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
datapath="/content/drive/MyDrive/Datasets"

# %%
import os
import numpy as np
import shutil
from sklearn.utils.class_weight import compute_class_weight
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, BatchNormalization
from tensorflow.keras.applications import ResNet50V2
from tensorflow.keras.applications.resnet_v2 import preprocess_input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint


#preprocessing and data augmentation
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    validation_split=0.2,
    rotation_range=15,
    zoom_range=0.2,
    width_shift_range=0.15,
    height_shift_range=0.15,
    shear_range=0.1,
    brightness_range=[0.85, 1.15],
    horizontal_flip=False
)

val_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    validation_split=0.2
)

# %%
train_data = train_datagen.flow_from_directory(
    datapath,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    subset='training',
    shuffle=True
)
# Out:
# Found 1422 images belonging to 7 classes.

# %%
val_data = val_datagen.flow_from_directory(
    datapath,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    subset='validation',
    shuffle=False
)


print("\nClass mapping:", train_data.class_indices)
print("Training samples:", train_data.samples)
print("Validation samples:", val_data.samples)
NUM_CLASSES = len(train_data.class_indices)
print("Number of classes:", NUM_CLASSES)
# Out:
# Found 352 images belonging to 7 classes.
#
# Class mapping: {'10': 0, '100': 1, '20': 2, '200': 3, '2000': 4, '50': 5, '500': 6}
# Training samples: 1422
# Validation samples: 352
# Number of classes: 7

# %%
checkpoints_path = os.path.join(datapath, '.ipynb_checkpoints')
if os.path.exists(checkpoints_path):
    shutil.rmtree(checkpoints_path)
    print("Cleaned .ipynb_checkpoints")

# %%
labels = train_data.classes
class_weights_array = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(labels),
    y=labels
)
class_weights = dict(enumerate(class_weights_array))
print("\nClass weights:", class_weights)
# Out:
# Class weights: {0: np.float64(0.7360248447204969), 1: np.float64(1.1285714285714286), 2: np.float64(0.8794063079777366), 3: np.float64(0.9318479685452162), 4: np.float64(2.4773519163763065), 5: np.float64(0.9582210242587601), 6: np.float64(0.9109545163356823)}

# %%
#base model
base = ResNet50V2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base.trainable = False

NUM_CLASSES = len(train_data.class_indices)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94668760/94668760 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
#classification model

model = Sequential([
    base,
    GlobalAveragePooling2D(),
    BatchNormalization(),
    Dense(256, activation='relu'),
    Dropout(0.3),
    Dense(NUM_CLASSES, activation='softmax')
])

# %%
callbacks = [
    EarlyStopping(monitor='val_accuracy', patience=5,
                  restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5,
                      patience=3, min_lr=1e-7, verbose=1),
    ModelCheckpoint('best_currex_model.keras',
                    monitor='val_accuracy', save_best_only=True, verbose=1)
]

# %%
print("\n=== Phase 1: Training head only (base frozen) ===")
model.compile(
    optimizer=Adam(learning_rate=1e-3),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history1 = model.fit(
    train_data,
    validation_data=val_data,
    epochs=10,
    class_weight=class_weights,
    callbacks=callbacks
)
# Out:
# === Phase 1: Training head only (base frozen) ===
# Epoch 1/10
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.5377 - loss: 1.4483
# Epoch 1: val_accuracy improved from None to 0.29830, saving model to best_currex_model.keras
#
# Epoch 1: finished saving model to best_currex_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 567s 12s/step - accuracy: 0.6688 - loss: 1.0488 - val_accuracy: 0.2983 - val_loss: 14.7050 - learning_rate: 0.0010
# Epoch 2/10
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.8932 - loss: 0.3451
# Epoch 2: val_accuracy improved from 0.29830 to 0.54830, saving model to best_currex_model.keras
#
# Epoch 2: finished saving model to best_currex_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 424s 9s/step - accuracy: 0.8790 - loss: 0.3930 - val_accuracy: 0.5483 - val_loss: 7.7591 - learning_rate: 0.0010
# Epoch 3/10
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.8907 - loss: 0.3764
# Epoch 3: val_accuracy did not improve from 0.54830
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 425s 9s/step - accuracy: 0.8903 - loss: 0.3757 - val_accuracy: 0.4233 - val_loss: 9.4295 - learning_rate: 0.0010
# Epoch 4/10
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9227 - loss: 0.2877
# Epoch 4: val_accuracy did not improve from 0.54830
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 431s 10s/step - accuracy: 0.9058 - loss: 0.3470 - val_accuracy: 0.4233 - val_loss: 11.3584 - learning_rate: 0.0010
# Epoch 5/10
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9242 - loss: 0.2238
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 5: val_accuracy did not improve from 0.54830
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 420s 9s/step - accuracy: 0.9093 - loss: 0.2597 - val_accuracy: 0.2670 - val_loss: 18.1658 - learning_rate: 0.0010
# Epoch 6/10
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9392 - loss: 0.1497
# Epoch 6: val_accuracy improved from 0.54830 to 0.64773, saving model to best_currex_model.keras
#
# Epoch 6: finished saving model to best_currex_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 456s 10s/step - accuracy: 0.9606 - loss: 0.1064 - val_accuracy: 0.6477 - val_loss: 1.5535 - learning_rate: 5.0000e-04
# Epoch 7/10
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9811 - loss: 0.0527
# Epoch 7: val_accuracy improved from 0.64773 to 0.73864, saving model to best_currex_model.keras
#
# Epoch 7: finished saving model to best_currex_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 430s 10s/step - accuracy: 0.9817 - loss: 0.0519 - val_accuracy: 0.7386 - val_loss: 0.9108 - learning_rate: 5.0000e-04
# Epoch 8/10
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9878 - loss: 0.0437
# Epoch 8: val_accuracy improved from 0.73864 to 0.74432, saving model to best_currex_model.keras
#
# Epoch 8: finished saving model to best_currex_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 424s 9s/step - accuracy: 0.9838 - loss: 0.0492 - val_accuracy: 0.7443 - val_loss: 0.8255 - learning_rate: 5.0000e-04
# Epoch 9/10
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9781 - loss: 0.0818
# Epoch 9: val_accuracy did not improve from 0.74432
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 427s 10s/step - accuracy: 0.9761 - loss: 0.0935 - val_accuracy: 0.7301 - val_loss: 0.9970 - learning_rate: 5.0000e-04
# Epoch 10/10
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9791 - loss: 0.0462
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_14852/4010941321.py in <cell line: 0>()
#       6 )
#       7
# ----> 8 history1 = model.fit(
#       9     train_data,
#      10     validation_data=val_data,
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     421                         shuffle=False,
#     422                     )
# --> 423                 val_logs = self.evaluate(
#     424                     x=val_x,
#     425                     y=val_y,
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, return_dict, **kwargs)
#     509             for begin_step, end_step, iterator in epoch_iterator:
#     510                 callbacks.on_test_batch_begin(begin_step)
# --> 511                 logs = self.test_function(iterator)
#     512                 callbacks.on_test_batch_end(end_step, logs)
#     513                 if self.stop_evaluating:
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in function(iterator)
#     239                 iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     240             ):
# --> 241                 opt_outputs = multi_step_on_iterator(iterator)
#     242                 if not opt_outputs.has_value():
#     243                     raise StopIteration
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     831
#     832       with OptionalXlaContext(self._jit_compile):
# --> 833         result = self._call(*args, **kwds)
#     834
#     835       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     876       # In this case we have not created variables on the first call. So we can
#     877       # run the first trace but we should fail if variables are created.
# --> 878       results = tracing_compilation.call_function(
#     879           args, kwds, self._variable_creation_config
#     880       )
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1320         and executing_eagerly):
#    1321       # No tape is watching; skip to running the function.
# -> 1322       return self._inference_function.call_preflattened(args)
#    1323     forward_backward = self._select_forward_and_backward_functions(
#    1324         args,
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1686     cancellation_context = cancellation.context()
#    1687     if cancellation_context is None:
# -> 1688       outputs = execute.execute(
#    1689           name.decode("utf-8"),
#    1690           num_outputs=num_outputs,
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
print("\n=== Phase 2: Fine-tuning top 30 layers ===")
base.trainable = True
for layer in base.layers[:-30]:
    layer.trainable = False

model.compile(
    optimizer=Adam(learning_rate=1e-5),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history2 = model.fit(
    train_data,
    validation_data=val_data,
    epochs=25,
    class_weight=class_weights,
    callbacks=callbacks
)
# Out:
# === Phase 2: Fine-tuning top 30 layers ===
# Epoch 1/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9894 - loss: 0.0310
# Epoch 1: val_accuracy improved from 0.74432 to 0.75568, saving model to best_currex_model.keras
#
# Epoch 1: finished saving model to best_currex_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 452s 10s/step - accuracy: 0.9866 - loss: 0.0410 - val_accuracy: 0.7557 - val_loss: 0.9550 - learning_rate: 1.0000e-05
# Epoch 2/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9859 - loss: 0.0323
# Epoch 2: val_accuracy improved from 0.75568 to 0.76420, saving model to best_currex_model.keras
#
# Epoch 2: finished saving model to best_currex_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 435s 10s/step - accuracy: 0.9859 - loss: 0.0378 - val_accuracy: 0.7642 - val_loss: 0.9723 - learning_rate: 1.0000e-05
# Epoch 3/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9897 - loss: 0.0358
# Epoch 3: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
#
# Epoch 3: val_accuracy did not improve from 0.76420
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 421s 9s/step - accuracy: 0.9873 - loss: 0.0308 - val_accuracy: 0.7642 - val_loss: 0.9790 - learning_rate: 1.0000e-05
# Epoch 4/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9894 - loss: 0.0345
# Epoch 4: val_accuracy did not improve from 0.76420
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 428s 10s/step - accuracy: 0.9866 - loss: 0.0338 - val_accuracy: 0.7614 - val_loss: 0.9978 - learning_rate: 5.0000e-06
# Epoch 5/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9897 - loss: 0.0230
# Epoch 5: val_accuracy did not improve from 0.76420
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 424s 9s/step - accuracy: 0.9880 - loss: 0.0250 - val_accuracy: 0.7614 - val_loss: 1.0028 - learning_rate: 5.0000e-06
# Epoch 6/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9916 - loss: 0.0253
# Epoch 6: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
#
# Epoch 6: val_accuracy did not improve from 0.76420
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 430s 10s/step - accuracy: 0.9916 - loss: 0.0262 - val_accuracy: 0.7614 - val_loss: 1.0050 - learning_rate: 5.0000e-06
# Epoch 7/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.9939 - loss: 0.0139
# Epoch 7: val_accuracy did not improve from 0.76420
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 424s 9s/step - accuracy: 0.9902 - loss: 0.0204 - val_accuracy: 0.7642 - val_loss: 1.0067 - learning_rate: 2.5000e-06
# Epoch 7: early stopping
# Restoring model weights from the end of the best epoch: 2.

# %%
loss, acc = model.evaluate(val_data, verbose=0)
print(f"\nFinal val accuracy : {acc*100:.2f}%")
print(f"Final val loss     : {loss:.4f}")
# Out:
# Final val accuracy : 76.42%
# Final val loss     : 0.9723
